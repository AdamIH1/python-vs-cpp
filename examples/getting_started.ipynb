# %% [markdown]
# ### Purpose
#  - show speed difference between python and c++ for loops
#  - this is a simple package mostly developed for learning and templating future C++ pybind11 work

# %% [markdown]
# #### Imports

# %%
import python_vs_cpp as pvc

# %%
help(pvc)
# Out:
# Help on package python_vs_cpp:
#
# NAME
#     python_vs_cpp
#
# PACKAGE CONTENTS
#     api (package)
#     loop_clocking (package)
#
# FUNCTIONS
#     compare_loop_speed(num_loops: Optional[int] = None, verbose: bool = True)
#         Run a loop speed comparison between Python and C++.
#
#         Args:
#             num_loops: Number of loops to run. If not provided, the user will
#                 be prompted to enter a value interactively.
#             verbose: If True, prints progress and results. If False, runs silently.
#
# DATA
#     __all__ = ['compare_loop_speed']
#
# VERSION
#     0.0.1dev
#
# FILE
#     /opt/anaconda3/lib/python3.11/site-packages/python_vs_cpp/__init__.py

# %% [markdown]
# #### Speed test
#   - defined or user input number of loops

# %%
test = pvc.compare_loop_speed()
# Out:
# --- Python Version ---
# Completed 900000 loops in 36.4735 ms
# ---C++ Version ---
# Completed 900000 loops in 0.6025 ms
# ---Comparison ---
# Python: 36.4735 ms
# C++:    0.6025 ms
# C++ is 60.53x faster

# %%
test = pvc.compare_loop_speed(num_loops=900000)
# Out:
# --- Python Version ---
# Completed 900000 loops in 35.3215 ms
# ---C++ Version ---
# Completed 900000 loops in 0.5854 ms
# ---Comparison ---
# Python: 35.3215 ms
# C++:    0.5854 ms
# C++ is 60.34x faster
